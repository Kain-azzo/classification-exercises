# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import env
import os
from pydataset import data

# %%
iris = data("iris")

# %%
iris.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
iris.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
iris.dtypes
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %%
iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
url = 'https://docs.google.com/spreadsheets/d/\
1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'

# %%
fixed_url = url.replace('/edit#gid=', '/export?format=csv&gid=')

# %%
df_google = pd.read_csv(fixed_url)

# %%
df_google.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df_google.shape
# Out:
# (891, 12)

# %%
df_google.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_google.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df_google.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_google.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
recol = df_google.columns [df_google.nunique() < 10]
recol
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked'], dtype='object')

# %%
for col in recol:
    print(col)
    print(df_google[col].value_counts())
    print()
# Out:
# Survived
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64
#
# Pclass
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
#
# Sex
# Sex
# male      577
# female    314
# Name: count, dtype: int64
#
# SibSp
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64
#
# Parch
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64
#
# Embarked
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df_google.Cabin.value_counts()
# Out:
# Cabin
# B96 B98            4
# G6                 4
# C23 C25 C27        4
# C22 C26            3
# F33                3
# F2                 3
# E101               3
# D                  3
# C78                2
# C93                2
# E8                 2
# D36                2
# B77                2
# C123               2
# E121               2
# E44                2
# D35                2
# C125               2
# E67                2
# B35                2
# B18                2
# E24                2
# B49                2
# C65                2
# B20                2
# B5                 2
# B57 B59 B63 B66    2
# C126               2
# B51 B53 B55        2
# F4                 2
# C124               2
# F G73              2
# B58 B60            2
# C52                2
# D33                2
# C68                2
# D20                2
# D26                2
# B28                2
# C83                2
# E25                2
# D17                2
# B22                2
# ...

# %%
df_google.Survived.value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df_google.Survived.astype(object)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: object

# %%
df_google.select_dtypes(include='object')
# Out:
#                                                     Name     Sex  \
# 0                                Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female
# 2                                 Heikkinen, Miss. Laina  female
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                               Allen, Mr. William Henry    male
# ..                                                   ...     ...
# 886                                Montvila, Rev. Juozas    male
# 887                         Graham, Miss. Margaret Edith  female
# 888             Johnston, Miss. Catherine Helen "Carrie"  female
# 889                                Behr, Mr. Karl Howell    male
# 890                                  Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# ...

# %%
telco1, titanic1, iris1 = "telco.csv", "titanic.csv", "iris.csv"

# %%
url = env.get_db_url('titanic_db')

# %%
titan = pd.read_sql(('SELECT * FROM passengers'), url)

# %%
def get_titanic_data():
    url = env.get_db_url("titanic_db")
    titan = pd.read_sql(('SELECT * FROM passengers'), url)
    return titan

# %%
get_titanic_data()
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class  deck  embark_town  alone
# ...

# %%
titan.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class  deck  embark_town  alone
# 0        S  Third  None  Southampton      0
# 1        C  First     C    Cherbourg      0
# 2        S  Third  None  Southampton      1
# 3        S  First     C  Southampton      0
# 4        S  Third  None  Southampton      1

# %%
iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_url = env.get_db_url('iris_db')

# %%
flower = 'SELECT * FROM species join measurements using (species_id)'

# %%
def get_iris_data():
#     if os.path.exists(iris1):
#         print('this file exists, reading from csv')
#         got_iris = pd.read_csv(iris1)
#     else:
#         print('this file doesnt exist, reading from sql and saving to csv')
#         #read from sql
#         no_iris = pd.read_sql(telco_cust, iris_url)
#         no_iris.to_csv(iris1)
    got_it2 = pd.read_sql(flower, iris_url)
    
    irises= pd.DataFrame(got_it2)
    return irises

# %%
get_iris_data()
# Out:
#      species_id species_name  measurement_id  sepal_length  sepal_width  \
# 0             1       setosa               1           5.1          3.5
# 1             1       setosa               2           4.9          3.0
# 2             1       setosa               3           4.7          3.2
# 3             1       setosa               4           4.6          3.1
# 4             1       setosa               5           5.0          3.6
# 5             1       setosa               6           5.4          3.9
# 6             1       setosa               7           4.6          3.4
# 7             1       setosa               8           5.0          3.4
# 8             1       setosa               9           4.4          2.9
# 9             1       setosa              10           4.9          3.1
# 10            1       setosa              11           5.4          3.7
# 11            1       setosa              12           4.8          3.4
# ...

# %%
telco_cust ='''select * from customers as cust
	left join contract_types as ct
		using(contract_type_id)
	left join internet_service_types as ist
		using(internet_service_type_id)
	left join payment_types as pt
        using(payment_type_id)
    '''

# %%
telco_url = env.get_db_url('telco_churn')

# %%
cust_data1 = "cust_data.csv"

# %%
def get_telco_data():
    got_it3 = pd.read_sql(telco_cust, telco_url)
    cust_data= pd.DataFrame(got_it3)
    return cust_data

# %%
get_telco_data().head()
# Out:
#    payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                2                         1                 2  0002-ORFBO
# 1                2                         1                 1  0003-MKNFE
# 2                1                         2                 1  0004-TLHLJ
# 3                1                         2                 1  0011-IGKFF
# 4                2                         2                 1  0013-EXCHZ
#
#    gender  senior_citizen partner dependents  tenure phone_service  ...  \
# 0  Female               0     Yes        Yes       9           Yes  ...
# 1    Male               0      No         No       9           Yes  ...
# 2    Male               0      No         No       4           Yes  ...
# 3    Male               1     Yes         No      13           Yes  ...
# 4  Female               1     Yes         No       3           Yes  ...
#
#   tech_support streaming_tv streaming_movies paperless_billing  \
# ...

# %%
import acquire

# %%
acquire.get_telco_data
# Out:
#       payment_type_id  internet_service_type_id customer_id  contract_type_id  \
# 0                   2                         1  0002-ORFBO                 2
# 1                   2                         1  0003-MKNFE                 1
# 2                   1                         2  0004-TLHLJ                 1
# 3                   1                         2  0011-IGKFF                 1
# 4                   2                         2  0013-EXCHZ                 1
# ...               ...                       ...         ...               ...
# 7038                2                         2  9979-RGMZT                 2
# 7039                2                         2  9985-MWVIX                 1
# 7040                3                         3  9986-BONCE                 1
# 7041                2                         1  9992-UJOEL                 1
# 7042                1                         1  9995-HOTOH                 3
#
# ...
