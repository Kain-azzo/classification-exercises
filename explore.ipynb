# %%
import warnings

warnings.filterwarnings('ignore')

# %%
from acquire import get_iris_data,get_telco_data

# %%
import scipy.stats as stats

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import env
import os
from prepare import chop_data, prep_iris,prep_telco
from pydataset import data

# %%
get_iris_data
# Out:
#      species_id  measurement_id  sepal_length  sepal_width  petal_length  \
# 0             1               1           5.1          3.5           1.4
# 1             1               2           4.9          3.0           1.4
# 2             1               3           4.7          3.2           1.3
# 3             1               4           4.6          3.1           1.5
# 4             1               5           5.0          3.6           1.4
# 5             1               6           5.4          3.9           1.7
# 6             1               7           4.6          3.4           1.4
# 7             1               8           5.0          3.4           1.5
# 8             1               9           4.4          2.9           1.4
# 9             1              10           4.9          3.1           1.5
# 10            1              11           5.4          3.7           1.5
# 11            1              12           4.8          3.4           1.6
# ...

# %%
prepped_iris = prep_iris(get_iris_data)

# %%
prepped_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
prepped_iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
prepped_iris.shape
# Out:
# (150, 5)

# %%
prepped_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...

# %%
train,validate,test = chop_data(prepped_iris,"species")

# %%
train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 24            4.8          3.4           1.9          0.2      setosa
# 147           6.5          3.0           5.2          2.0   virginica
# 88            5.6          3.0           4.1          1.3  versicolor
# 123           6.3          2.7           4.9          1.8   virginica
# 31            5.4          3.4           1.5          0.4      setosa
# 54            6.5          2.8           4.6          1.5  versicolor
# 11            4.8          3.4           1.6          0.2      setosa
# 97            6.2          2.9           4.3          1.3  versicolor
# 35            5.0          3.2           1.2          0.2      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 89            5.5          2.5           4.0          1.3  versicolor
# 137           6.4          3.1           5.5          1.8   virginica
# ...

# %%
validate
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 144           6.7          3.3           5.7          2.5   virginica
# 125           7.2          3.2           6.0          1.8   virginica
# 100           6.3          3.3           6.0          2.5   virginica
# 43            5.0          3.5           1.6          0.6      setosa
# 91            6.1          3.0           4.6          1.4  versicolor
# 72            6.3          2.5           4.9          1.5  versicolor
# 17            5.1          3.5           1.4          0.3      setosa
# 61            5.9          3.0           4.2          1.5  versicolor
# 63            6.1          2.9           4.7          1.4  versicolor
# 116           6.5          3.0           5.5          1.8   virginica
# 51            6.4          3.2           4.5          1.5  versicolor
# 32            5.2          4.1           1.5          0.1      setosa
# ...

# %%
test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 22            4.6          3.6           1.0          0.2      setosa
# 25            5.0          3.0           1.6          0.2      setosa
# 86            6.7          3.1           4.7          1.5  versicolor
# 34            4.9          3.1           1.5          0.2      setosa
# 76            6.8          2.8           4.8          1.4  versicolor
# 135           7.7          3.0           6.1          2.3   virginica
# 42            4.4          3.2           1.3          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 75            6.6          3.0           4.4          1.4  versicolor
# 93            5.0          2.3           3.3          1.0  versicolor
# 66            5.6          3.0           4.5          1.5  versicolor
# 68            6.2          2.2           4.5          1.5  versicolor
# ...

# %%
for col in prepped_iris.columns:
    if prepped_iris[col].dtype == "float64":
        print(col)
        print(prepped_iris[col].value_counts(bins=10).sort_index())
        prepped_iris[col].hist()
        plt.show()
# Out:
# sepal_length
# (4.295, 4.66]     9
# (4.66, 5.02]     23
# (5.02, 5.38]     14
# (5.38, 5.74]     27
# (5.74, 6.1]      22
# (6.1, 6.46]      20
# (6.46, 6.82]     18
# (6.82, 7.18]      6
# (7.18, 7.54]      5
# (7.54, 7.9]       6
# Name: count, dtype: int64
# sepal_width
# (1.997, 2.24]     4
# (2.24, 2.48]      7
# (2.48, 2.72]     22
# (2.72, 2.96]     24
# (2.96, 3.2]      50
# (3.2, 3.44]      18
# (3.44, 3.68]     10
# (3.68, 3.92]     11
# (3.92, 4.16]      2
# (4.16, 4.4]       2
# Name: count, dtype: int64
# petal_length
# (0.993, 1.59]    37
# (1.59, 2.18]     13
# (2.18, 2.77]      0
# (2.77, 3.36]      3
# (3.36, 3.95]      8
# (3.95, 4.54]     26
# (4.54, 5.13]     29
# (5.13, 5.72]     18
# (5.72, 6.31]     11
# (6.31, 6.9]       5
# Name: count, dtype: int64
# petal_width
# (0.0966, 0.34]    41
# (0.34, 0.58]       8
# (0.58, 0.82]       1
# (0.82, 1.06]       7
# (1.06, 1.3]       21
# (1.3, 1.54]       20
# (1.54, 1.78]       6
# (1.78, 2.02]      23
# ...

# %%
prepped_iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
sns.boxplot(data=train, x='species', y='petal_length')
plt.show()

# %%
sns.boxplot(data=train, x='species', y='petal_length')
plt.show()

# %%
sns.boxplot(data=train, x='species', y='sepal_width')
plt.show()

# %%
prepped_iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
prepped_iris.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
prepped_iris.species.value_counts()
plt.show()

# %%
prepped_iris.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
prepped_iris.species.value_counts().index
# Out:
# Index(['setosa', 'versicolor', 'virginica'], dtype='object', name='species')

# %%
sns.barplot(data=prepped_iris, 
            y=prepped_iris.species.value_counts(),
            x=prepped_iris.species.value_counts().index);

# %%
mean = prepped_iris.petal_length.mean()

sns.barplot(data=prepped_iris, 
            y=prepped_iris.petal_length,
            x=prepped_iris.species)
plt.axhline(mean, label="length_mean");
prepped_iris.petal_length.describe()
# Out:
# count    150.000000
# mean       3.758000
# std        1.765298
# min        1.000000
# 25%        1.600000
# 50%        4.350000
# 75%        5.100000
# max        6.900000
# Name: petal_length, dtype: float64

# %%
mean2 = prepped_iris.petal_width.mean()


sns.barplot(data=prepped_iris, 
            y=prepped_iris.petal_width,
            x=prepped_iris.species)
plt.axhline(mean2, label="width_mean");
prepped_iris.petal_width.describe()
# Out:
# count    150.000000
# mean       1.199333
# std        0.762238
# min        0.100000
# 25%        0.300000
# 50%        1.300000
# 75%        1.800000
# max        2.500000
# Name: petal_width, dtype: float64

# %%
mean3 = prepped_iris.sepal_width.mean()

sns.barplot(data=prepped_iris, 
            y=prepped_iris.sepal_width,
            x=prepped_iris.species)
plt.axhline(mean3, label="width_mean")
prepped_iris.sepal_width.describe()
# Out:
# count    150.000000
# mean       3.057333
# std        0.435866
# min        2.000000
# 25%        2.800000
# 50%        3.000000
# 75%        3.300000
# max        4.400000
# Name: sepal_width, dtype: float64

# %%
mean4 = prepped_iris.sepal_length.mean()

sns.barplot(data=prepped_iris, 
            y=prepped_iris.sepal_length,
            x=prepped_iris.species)
plt.axhline(mean4, label="length_mean")
prepped_iris.sepal_length.describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64

# %%
prepped_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
prepped_iris[prepped_iris["species"] == "versicolor"].petal_width
# Out:
# 50    1.4
# 51    1.5
# 52    1.5
# 53    1.3
# 54    1.5
# 55    1.3
# 56    1.6
# 57    1.0
# 58    1.3
# 59    1.4
# 60    1.0
# 61    1.5
# 62    1.0
# 63    1.4
# 64    1.3
# 65    1.4
# 66    1.5
# 67    1.0
# 68    1.5
# 69    1.1
# 70    1.8
# 71    1.3
# 72    1.5
# 73    1.2
# 74    1.3
# 75    1.4
# 76    1.4
# 77    1.7
# 78    1.5
# 79    1.0
# 80    1.1
# 81    1.0
# 82    1.2
# 83    1.6
# 84    1.5
# 85    1.6
# 86    1.5
# 87    1.3
# 88    1.3
# 89    1.3
# 90    1.2
# 91    1.4
# 92    1.2
# 93    1.0
# 94    1.3
# 95    1.2
# 96    1.3
# 97    1.3
# 98    1.1
# 99    1.3
# Name: petal_width, dtype: float64

# %%
versi = prepped_iris[prepped_iris["species"] == "versicolor"].petal_width

# %%
virg = prepped_iris[prepped_iris["species"] == "virginica"].petal_width

# %%
statistic3, p_value3 = stats.mannwhitneyu(versi,virg)

# %%
p_value3
# Out:
# 9.698045444914185e-17

# %%
statistic3
# Out:
# 49.0

# %% [markdown]
# less than alpha, so reject null hypothesis-- significant difference

# %%
get_telco_data
# Out:
#       payment_type_id  internet_service_type_id customer_id  contract_type_id  \
# 0                   2                         1  0002-ORFBO                 2
# 1                   2                         1  0003-MKNFE                 1
# 2                   1                         2  0004-TLHLJ                 1
# 3                   1                         2  0011-IGKFF                 1
# 4                   2                         2  0013-EXCHZ                 1
# ...               ...                       ...         ...               ...
# 7038                2                         2  9979-RGMZT                 2
# 7039                2                         2  9985-MWVIX                 1
# 7040                3                         3  9986-BONCE                 1
# 7041                2                         1  9992-UJOEL                 1
# 7042                1                         1  9995-HOTOH                 3
#
# ...

# %%
clean_telco = prep_telco(get_telco_data)

# %%
clean_telco
# Out:
#      customer_id paperless_billing   contract_type churn_month  gender  \
# 0     0002-ORFBO               Yes        One year         NaN  Female
# 1     0003-MKNFE                No  Month-to-month         NaN    Male
# 2     0004-TLHLJ               Yes  Month-to-month  2022-01-31    Male
# 3     0011-IGKFF               Yes  Month-to-month  2022-01-31    Male
# 4     0013-EXCHZ               Yes  Month-to-month  2022-01-31  Female
# ...          ...               ...             ...         ...     ...
# 7038  9979-RGMZT               Yes        One year         NaN  Female
# 7039  9985-MWVIX               Yes  Month-to-month  2022-01-31  Female
# 7040  9986-BONCE                No  Month-to-month  2022-01-31  Female
# 7041  9992-UJOEL               Yes  Month-to-month         NaN    Male
# 7042  9995-HOTOH                No        Two year         NaN    Male
#
#       senior_citizen partner dependents  monthly_charges total_charges  ...  \
# ...

# %%
train2,validate2,test2 = chop_data(clean_telco)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[253], line 1
# ----> 1 train2,validate2,test2 = chop_data(clean_telco)
#
# TypeError: chop_data() missing 1 required positional argument: 'col'
