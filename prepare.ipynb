# %%
from acquire import get_iris_data
# Out:
# this file exists, reading csv
# this file exists, reading csv
# this file exists, reading csv

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import env
import os
from pydataset import data

# %%
get_iris_data
# Out:
#      species_id  measurement_id  sepal_length  sepal_width  petal_length  \
# 0             1               1           5.1          3.5           1.4
# 1             1               2           4.9          3.0           1.4
# 2             1               3           4.7          3.2           1.3
# 3             1               4           4.6          3.1           1.5
# 4             1               5           5.0          3.6           1.4
# 5             1               6           5.4          3.9           1.7
# 6             1               7           4.6          3.4           1.4
# 7             1               8           5.0          3.4           1.5
# 8             1               9           4.4          2.9           1.4
# 9             1              10           4.9          3.1           1.5
# 10            1              11           5.4          3.7           1.5
# 11            1              12           4.8          3.4           1.6
# ...

# %%
get_iris_data.drop(columns='species_id')
# Out:
#      measurement_id  sepal_length  sepal_width  petal_length  petal_width  \
# 0                 1           5.1          3.5           1.4          0.2
# 1                 2           4.9          3.0           1.4          0.2
# 2                 3           4.7          3.2           1.3          0.2
# 3                 4           4.6          3.1           1.5          0.2
# 4                 5           5.0          3.6           1.4          0.2
# 5                 6           5.4          3.9           1.7          0.4
# 6                 7           4.6          3.4           1.4          0.3
# 7                 8           5.0          3.4           1.5          0.2
# 8                 9           4.4          2.9           1.4          0.2
# 9                10           4.9          3.1           1.5          0.1
# 10               11           5.4          3.7           1.5          0.2
# 11               12           4.8          3.4           1.6          0.2
# ...

# %%
get_iris_data = get_iris_data.drop(columns='species_id')

# %%
get_iris_data = get_iris_data.drop(columns= "measurement_id")

# %%
get_iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width species_name
# 0             5.1          3.5           1.4          0.2       setosa
# 1             4.9          3.0           1.4          0.2       setosa
# 2             4.7          3.2           1.3          0.2       setosa
# 3             4.6          3.1           1.5          0.2       setosa
# 4             5.0          3.6           1.4          0.2       setosa
# 5             5.4          3.9           1.7          0.4       setosa
# 6             4.6          3.4           1.4          0.3       setosa
# 7             5.0          3.4           1.5          0.2       setosa
# 8             4.4          2.9           1.4          0.2       setosa
# 9             4.9          3.1           1.5          0.1       setosa
# 10            5.4          3.7           1.5          0.2       setosa
# 11            4.8          3.4           1.6          0.2       setosa
# ...

# %%
get_iris_data = get_iris_data.rename(columns={"species_name":"species"})

# %%
def prep_iris(flower):
    flower = flower.rename(columns={"species_name":"species"})
    flower = flower.drop(columns=['species_id','measurement_id'])
    return flower

# %%
new_flower = get_iris_data

# %%
new_flower
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...

# %%
prep_iris(new_flower)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 prep_iris(new_flower)
#
# Cell In[9], line 3, in prep_iris(flower)
#       1 def prep_iris(flower):
#       2     flower = flower.rename(columns={"species_name":"species"})
# ----> 3     flower = flower.drop(columns=['species_id','measurement_id'])
#       4     return flower
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# ...

# %%
new_flower

# %%
import acquire

# %%
telco = acquire.get_telco_data

# %%
telco.internet_service_type.value_counts()

# %%
telco.isnull().sum()

# %%
telco.info()

# %%
telco.phone_service.describe()

# %%
telco.phone_service.info()

# %%
telco.phone_service

# %%
telco.churn_month.info()

# %%
telco.churn_month.describe()

# %%
telco.churn_month.value_counts()

# %%
import pandas as pd

# %%
churnm = pd.DataFrame(telco.churn_month)

# %%
telco.drop(columns=['payment_type_id','internet_service_type_id','contract_type_id'])

# %%
telco.total_charges.str.replace(' ', '0.0')

# %%
telco.total_charges.value_counts()

# %%
churnm

# %%
telco.info()

# %%
def prep_telco(isp):
    isp = isp.drop(columns = ['payment_type_id','internet_service_type_id','contract_type_id'])
    isp.total_charges = isp.total_charges.str.replace(' ', '0.0')
    return isp

# %%
telco5 = acquire.get_telco_data

# %%
prep_telco(telco5)
